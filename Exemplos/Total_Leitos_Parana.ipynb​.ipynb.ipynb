# %%
# !pip install git+https://github.com/AlertaDengue/PySUS.git --upgrade
# Out:
# ...
#   Cloning https://github.com/AlertaDengue/PySUS.git to /tmp/pip-req-build-1qi_0x4w
#   Running command git clone --filter=blob:none --quiet https://github.com/AlertaDengue/PySUS.git /tmp/pip-req-build-1qi_0x4w
#   Resolved https://github.com/AlertaDengue/PySUS.git to commit 54f7800db4da5171d55e3446d638d64beeb8b149
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# Baseado em: CNES/CNES_LT.ipynb

from pysus.online_data.CNES import download

# Baixa os dados da base de Leitos (LT) para o Paraná, jan/2023
df = download('LT', 'PR', 2023, 1).to_dataframe()

# Visualiza as primeiras linhas para entender as colunas
df.head()
# Out:
# LTPR2301.parquet: 100%|██████████| 1.80k/1.80k [00:00<00:00, 5.96kB/s]
#       CNES CODUFMUN REGSAUDE MICR_REG DISTRSAN DISTRADM TPGESTAO PF_PJ  \
# 0  0013102   410020     2      410020                          D     3
# 1  0013129   410030     02                                     D     3
# 2  0013129   410030     02                                     D     3
# 3  0013129   410030     02                                     D     3
# 4  2733528   410045     011                                    M     3
#
#          CPF_CNPJ NIV_DEP  ... NIV_HIER TERCEIRO TP_LEITO CODLEITO QT_EXIST  \
# 0  00000000000000       3  ...                         2        33        3
# 1  00000000000000       3  ...                         5        45        1
# 2  00000000000000       3  ...                         4        43        1
# 3  00000000000000       3  ...                         2        33       10
# 4  00000000000000       3  ...                         4        10        2
#
# ...

# %%
# Converte TP_LEITO para número
df['TP_LEITO'] = pd.to_numeric(df['TP_LEITO'], errors='coerce')

# Filtra os registros com tipo SUS (1)
df_sus = df[df['TP_LEITO'] == 1]

# Cria uma nova coluna já convertida para números
df_sus = df_sus.copy()
df_sus['QT_EXIST'] = pd.to_numeric(df_sus['QT_EXIST'].astype(str), errors='coerce')

# Soma total
total_sus = df_sus['QT_EXIST'].sum()
print(f'Total de leitos SUS no Paraná (jan/2023): {int(total_sus)}')
# Out:
# Total de leitos SUS no Paraná (jan/2023): 7035
