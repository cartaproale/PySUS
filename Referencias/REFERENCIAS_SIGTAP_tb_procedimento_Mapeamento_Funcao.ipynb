# %%
# ✅ Notebook: Tabela de Procedimentos SIGTAP (tb_procedimento.txt)

# 🔹 Etapa 1: Importar bibliotecas
import pandas as pd

# 🔹 Etapa 2: Definir o link para o arquivo txt de largura fixa
url = "https://raw.githubusercontent.com/cartaproale/PySUS/main/tabelas/tb_procedimento.txt"

# 🔹 Etapa 3: Ler o arquivo com largura fixa (fixed-width format)
df = pd.read_fwf(url, widths=[10, 120], names=["codigo", "descricao"], encoding="latin1", dtype=str)

# 🔹 Etapa 4: Visualizar as primeiras linhas
print("Amostra da tabela de procedimentos:")
display(df.head())

# 🔹 Etapa 5: Criar função de mapeamento
def descricao_procedimento(codigo):
    resultado = df.loc[df['codigo'] == codigo, 'descricao']
    if not resultado.empty:
        return resultado.values[0]
    else:
        return "Código não encontrado"

# 🔹 Etapa 6: Exemplo de uso
print("\nExemplo de uso da função:")
exemplo = "0101010028"
print(f"Código: {exemplo} → Descrição: {descricao_procedimento(exemplo)}")
# Out:
# Amostra da tabela de procedimentos:
#        codigo                                          descricao
# 0  0101010010  ATIVIDADE EDUCATIVA / ORIENTAÇÃO EM GRUPO NA A...
# 1  0101010028  ATIVIDADE EDUCATIVA / ORIENTAÇÃO EM GRUPO NA A...
# 2  0101010036       PRÁTICA CORPORAL / ATIVIDADE FÍSICA EM GRUPO
# 3  0101010095                  PREVENÇÃO DA COVID-19 NAS ESCOLAS
# 4  0101010109  ATIVIDADES EDUCATIVAS DA POPULAÇÃO SOBRE A TEM...
# Exemplo de uso da função:
# Código: 0101010028 → Descrição: ATIVIDADE EDUCATIVA / ORIENTAÇÃO EM GRUPO NA ATENÇÃO ESPECIALIZADA
